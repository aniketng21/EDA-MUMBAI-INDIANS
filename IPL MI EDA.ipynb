# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
file = "C:/Users/ANIKET GAIKWAD/Desktop/deliveries.csv"
df = pd.read_csv(file)

# %%
df =df.replace('Sunrisers Hyderabad', 'SRH')
df =df.replace('Royal Challengers Bangalore', 'RCB')
df =df.replace('Mumbai Indians', 'MI')
df =df.replace('Rising Pune Supergiant', 'RPS')
df =df.replace('Gujarat Lions', 'GL')
df =df.replace('Kings XI Punjab', 'KXIP')
df =df.replace('Kolkata Knight Riders', 'KKR')
df =df.replace('Chennai Super Kings', 'CSK')
df =df.replace('Deccan Chargers', 'DC')
df =df.replace('Pune Warriors', 'PWI')
df =df.replace('Kochi Tuskers Kerala', 'KT')
df =df.replace('Rajasthan Royals', 'RR')
df=df.replace('Delhi Daredevils', 'DD')
df =df.replace('Rising Pune Supergiants', 'RPS')

df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
dfmi1 = df[df['batting_team']=='MI']
dfmi2 = df[df['bowling_team']=='MI']
dfmi = pd.concat([dfmi1,dfmi2])
dfmi.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball     batsman  \
# 248         2       1           MI          RPS     1     1    PA Patel
# 249         2       1           MI          RPS     1     2    PA Patel
# 250         2       1           MI          RPS     1     3    PA Patel
# 251         2       1           MI          RPS     1     4  JC Buttler
# 252         2       1           MI          RPS     1     5    PA Patel
#
#     non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 248  JC Buttler  AB Dinda              0  ...         0            0
# 249  JC Buttler  AB Dinda              0  ...         0            0
# 250  JC Buttler  AB Dinda              0  ...         0            0
# 251    PA Patel  AB Dinda              0  ...         0            0
# 252  JC Buttler  AB Dinda              0  ...         0            0
#
#      noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
dfmi1['batsman'].value_counts()
# Out:
# RG Sharma            2365
# SR Tendulkar         2044
# AT Rayudu            1964
# KA Pollard           1674
# LMP Simmons           878
# PA Patel              724
# KD Karthik            639
# Harbhajan Singh       591
# ST Jayasuriya         573
# DR Smith              494
# JP Duminy             468
# DJ Bravo              401
# SS Tiwary             397
# JC Buttler            375
# N Rana                355
# AM Nayar              348
# KH Pandya             313
# JEC Franklin          309
# HH Pandya             306
# RV Uthappa            291
# CJ Anderson           284
# AP Tare               245
# S Dhawan              226
# MEK Hussey            187
# AM Rahane             147
# A Symonds             143
# R Sathish             133
# CM Gautam             116
# SM Pollock            116
# SL Malinga            103
#                      ...
# Z Khan                 31
# JJ Bumrah              27
# GJ Maxwell             27
# S Gopal                27
# ...

# %% [markdown]
# # RUN ANALYSIS : ROHIT SHARMA

# %%
rgsharma = dfmi1[dfmi1['batsman']=='RG Sharma']
rgsharma.head(10000)
# Out:
#         match_id  inning batting_team bowling_team  over  ball    batsman  \
# 275            2       1           MI          RPS     5     3  RG Sharma
# 276            2       1           MI          RPS     5     4  RG Sharma
# 278            2       1           MI          RPS     5     6  RG Sharma
# 279            2       1           MI          RPS     6     1  RG Sharma
# 285            2       1           MI          RPS     7     1  RG Sharma
# 286            2       1           MI          RPS     7     2  RG Sharma
# 287            2       1           MI          RPS     7     3  RG Sharma
# 1609           7       2           MI          KKR     9     4  RG Sharma
# 1610           7       2           MI          KKR     9     5  RG Sharma
# 1612           7       2           MI          KKR    10     1  RG Sharma
# 1613           7       2           MI          KKR    10     2  RG Sharma
# 1614           7       2           MI          KKR    10     3  RG Sharma
# ...

# %%
rgsharma['extra_runs'].value_counts()
# Out:
# 0    2300
# 1      58
# 2       4
# 4       2
# 3       1
# Name: extra_runs, dtype: int64

# %%
rgsavg = rgsharma[['bowling_team','extra_runs','total_runs']].head(200000)

# %%
rgsavg1 = rgsavg.groupby(['bowling_team']).sum().reset_index()

# %%
rgsavg1.head(100000)
# Out:
#    bowling_team  extra_runs  total_runs
# 0           CSK           9         453
# 1            DC           3         178
# 2            DD          11         496
# 3            GL           0          82
# 4           KKR          20         614
# 5          KXIP           8         290
# 6           PWI           2         137
# 7           RCB          12         312
# 8           RPS           6         184
# 9            RR           6         199
# 10          SRH           0         169

# %%
rgsavg1['total_runs'].sum()
# Out:
# 3114

# %%
rgsavg1['extra_runs'].sum()
# Out:
# 77

# %%
rgsharma['match_id'].head()
# Out:
# 275    2
# 276    2
# 278    2
# 279    2
# 285    2
# Name: match_id, dtype: int64

# %%
rgsharmat = rgsharma.groupby(['match_id']).sum().reset_index()

# %%
rgsharmat.head()
# Out:
#    match_id  inning  over  ball  is_super_over  wide_runs  bye_runs  \
# 0         2       7    42    20              0          0         0
# 1         7      12    58    20              0          0         0
# 2        10       8    18    11              0          0         0
# 3        12       4     5    10              0          0         0
# 4        16      58   440   107              0          0         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 0            0            0             0             3           0
# 1            0            0             0             2           0
# 2            0            0             0             4           0
# 3            0            0             0             0           0
# 4            0            0             0            40           0
#
#    total_runs
# 0           3
# 1           2
# 2           4
# 3           0
# 4          40

# %%
rgsharmamatches = rgsharma['match_id'].unique()

# %%
len(rgsharmamatches)

# %%
rgsharma1 = rgsharma[rgsharma['extra_runs']!=0].head(5000)

# %%
rgsharma1['total_runs'].value_counts() #Extra runs when rohit was batting

# %% [markdown]
# ## HOW ROHIT SCORES HIS RUNS :

# %%
rgsharma['total_runs'].value_counts() #total runs when rohit was batting

# %% [markdown]
# ## TOTAL RUNS (2008 -2017)

# %%
rgsharma['total_runs'].sum() - 86#rohit's total runs

# %% [markdown]
# ## ROHIT AGAINST DIFFERENT BOWLERS:

# %%
rgsharma11 = rgsharma[['bowler','batsman_runs']].head(5000)

# %%
rgsharmab = rgsharma11.groupby(['bowler']).sum().reset_index()

# %%
rgsharmab.sort_values(by =['batsman_runs'],ascending = False)

# %% [markdown]
# ## ROHIT'S DISMISSAL ANALYSIS :

# %%
rgswicket = rgsharma[rgsharma['player_dismissed']== 'RG Sharma'].head(500)

# %%
rgswicket.head(500)

# %% [markdown]
# ## ROHIT'S WICKET-TAKERS IN IPL(2008-2017)

# %%
rgswicket['bowler'].value_counts()

# %% [markdown]
# ## ROHIT'S DISMISSAL KIND :

# %%
rgswicket['dismissal_kind'].value_counts()

# %% [markdown]
# # RUN ANALYSIS : SACHIN TENDULKAR

# %%
srt = dfmi1[dfmi1['batsman']=='SR Tendulkar'].head(5000)

# %%
srt1 = srt[srt['extra_runs']!=0].head(5000)

# %%
srt1['total_runs'].value_counts() # extra runs scored when sachin was batting

# %%
srt['total_runs'].value_counts()  #total runs scored when sachin was batting

# %% [markdown]
# ## TOTAL RUNS SCORED BY SR TENDULKAR IN IPL (2008 - 2017)

# %%
srt['total_runs'].sum() - 206 #total runs by sachin
